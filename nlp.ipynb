# %%
import PyPDF2
import pandas as pd

def extract_text_from_pdf(pdf_file):
    # Open the PDF file
    with open(pdf_file, 'rb') as file:
        # Create a PDF reader object
        pdf_reader = PyPDF2.PdfReader (file)
        # Initialize an empty string to store the extracted text
        text = ''
        # Iterate through each page in the PDF
        for page_num in range(len(pdf_reader.pages)):
            # Extract text from the current page
            page = pdf_reader.pages[page_num]
            text += page.extract_text ()
    return text

# Example PDF file path
pdf_file = 'Thinking-Fast-and-Slow.pdf'

# Extract text from PDF
pdf_text = extract_text_from_pdf(pdf_file)

# Create a DataFrame to store the extracted text
df = pd.DataFrame({'Text': [pdf_text]})

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 22
#      19 pdf_file = 'Thinking-Fast-and-Slow.pdf'
#      21 # Extract text from PDF
# ---> 22 pdf_text = extract_text_from_pdf(pdf_file)
#      24 # Create a DataFrame to store the extracted text
#      25 df = pd.DataFrame({'Text': [pdf_text]})
#
# Cell In[1], line 15, in extract_text_from_pdf(pdf_file)
#      12     for page_num in range(len(pdf_reader.pages)):
#      13         # Extract text from the current page
#      14         page = pdf_reader.pages[page_num]
# ---> 15         text += page.extract_text ()
#      16 return text
#
# File c:\Users\hp\anaconda3\Lib\site-packages\PyPDF2\_page.py:1851, in PageObject.extract_text(self, Tj_sep, TJ_sep, orientations, space_width, visitor_operand_before, visitor_operand_after, visitor_text, *args)
#    1848 if isinstance(orientations, int):
# ...

# %%
string = df['Text'].iloc[0]

# %%
import pickle as pk
# with open('text.pkl','wb') as file :
#     pk.dump(string,  file)

# %%
import nltk 
from nltk.corpus import stopwords
from nltk import SnowballStemmer, PorterStemmer, LancasterStemmer
from nltk.tokenize import word_tokenize, TreebankWordTokenizer
import string 
import pandas as pd

# %%
nltk.download(['punkt','stopwords'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
with open('text.pkl' , 'rb') as file :
    s = pk.load(file)

# %%
def remove_punctuation(post):
    return ''.join([l for l in post if l not in string.punctuation])

string2 = remove_punctuation(s)

# %%
string3 = string2.replace('\t'," ").replace('\n'," ")

# %%
tkn = TreebankWordTokenizer()
string4 = tkn.tokenize(string3)

string4
# Out:
# ['PIn',
#  'memory',
#  'of',
#  'Amos',
#  'Tversky',
#  'PContents',
#  'Introduction',
#  'Part',
#  'I',
#  'Two',
#  'Systems',
#  '1',
#  'The',
#  'Characters',
#  'of',
#  'the',
#  'Story',
#  '2',
#  'Attention',
#  'and',
#  'Effort',
#  '3',
#  'The',
#  'Lazy',
#  'Controller',
#  '4',
#  'The',
#  'Associative',
#  'Machine',
#  '5',
#  'Cognitive',
#  'Ease',
#  '6',
#  'Norms',
#  'Surprises',
#  'and',
#  'Causes',
#  '7',
#  'A',
#  'Machine',
#  'for',
#  'Jumping',
#  'to',
#  'Conclusions',
#  '8',
#  'How',
#  'Judgments',
#  'Happen',
#  '9',
#  'Answering',
#  'an',
#  'Easier',
#  'Question',
#  'Part',
#  'II',
#  'Heuristics',
#  'and',
#  'Biases',
#  '10',
#  'The',
#  'Law',
#  'of',
#  'Small',
#  'Numbers',
#  '5',
#  '11',
#  'Anchors',
#  '12',
#  'The',
#  'Science',
#  'of',
#  'Availability',
#  '13',
#  'Availability',
#  'Emotion',
#  'and',
#  'Risk',
#  '14',
#  'Tom',
#  'W’s',
#  'Specialty',
#  '15',
#  'Linda',
#  'Less',
#  'is',
# ...

# %%
string5 = [wrd.lower() for wrd in string5]

# %%
string5
# Out:
# ['pin',
#  'memory',
#  'amos',
#  'tversky',
#  'pcontents',
#  'introduction',
#  'part',
#  'i',
#  'two',
#  'systems',
#  '1',
#  'the',
#  'characters',
#  'story',
#  '2',
#  'attention',
#  'effort',
#  '3',
#  'the',
#  'lazy',
#  'controller',
#  '4',
#  'the',
#  'associative',
#  'machine',
#  '5',
#  'cognitive',
#  'ease',
#  '6',
#  'norms',
#  'surprises',
#  'causes',
#  '7',
#  'a',
#  'machine',
#  'jumping',
#  'conclusions',
#  '8',
#  'how',
#  'judgments',
#  'happen',
#  '9',
#  'answering',
#  'easier',
#  'question',
#  'part',
#  'ii',
#  'heuristics',
#  'biases',
#  '10',
#  'the',
#  'law',
#  'small',
#  'numbers',
#  '5',
#  '11',
#  'anchors',
#  '12',
#  'the',
#  'science',
#  'availability',
#  '13',
#  'availability',
#  'emotion',
#  'risk',
#  '14',
#  'tom',
#  'w’s',
#  'specialty',
#  '15',
#  'linda',
#  'less',
#  'more',
#  '16',
#  'causes',
#  'trump',
#  'statistics',
#  '17',
#  'regression',
#  'mean',
#  '18',
#  'taming',
# ...

# %%
stemmer = SnowballStemmer('english')
stemmer2 =  PorterStemmer()
# stemmer3 =  LancasterStemmer('english')
stem = [stemmer.stem(wrd) for wrd in string5 ]
stem2 = [stemmer2.stem(wrd) for wrd in string5 ]
# stem3 = [stemmer3.stem(wrd) for wrd in string5 ]

# %%
# print(stem)
df2 = pd.DataFrame({"text":stem})
df2
# Out:
#                 text
# 0                pin
# 1             memori
# 2                amo
# 3            tverski
# 4           pcontent
# ...              ...
# 110410  psychologist
# 110411           vol
# 110412            34
# 110413          1984
# 110414            pp
#
# [110415 rows x 1 columns]

# %%
df2.groupby('text').size().sort_values(ascending=False).head(30)
# Out:
# text
# the         1760
# i            669
# peopl        569
# one          552
# system       529
# probabl      477
# would        474
# experi       466
# two          455
# in           422
# a            418
# decis        417
# effect       416
# make         392
# 1            381
# question     358
# like         350
# differ       344
# also         336
# problem      326
# predict      323
# loss         323
# time         318
# intuit       317
# much         310
# mani         301
# choic        295
# judgment     294
# 2            294
# risk         290
# dtype: int64

# %%
string_to_remove = ['1','a','in' ,'the' ,'i' ,'would','also']

df3 = df2[ df2['text'].isin(string_to_remove)  ]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2408\89457466.py in ?()
#       1 string_to_remove = ['1','a','in' ,'the' ,'i' ,'would','also']
#       2
# ----> 3 df3 = df2[not df2['text'].isin(string_to_remove)  ]
#
# c:\Users\hp\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df3[df3['text']=="the"]
# Out:
#        text
# 11      the
# 18      the
# 22      the
# 50      the
# 58      the
# ...     ...
# 109145  the
# 110036  the
# 110091  the
# 110182  the
# 110348  the
#
# [1760 rows x 1 columns]

# %%
True ==  False
# Out:
# False
